# %% [markdown]
# <a href="https://colab.research.google.com/github/tomas151/ComputerVision_Colab1/blob/main/%EC%A0%95%EC%82%BC%EC%9A%A9_24912228_%EC%BB%B4%ED%93%A8%ED%84%B0AI%EA%B3%B5%ED%95%99%EA%B3%BC_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. 코랩파일에 제목을 [이름_학번_학과]로 수정하고,
#
#    - 첫 텍스트 셀에 제목으로 [AI활용영상데이터처리미니프로젝트] 을 제일 큰 마크다운 언어 Heading1로 표기
#
#    - [날짜]와 [본인의 이름]과 [학과]를 Heading 3로 명시해주세요.

# %% [markdown]
# #[AI활용영상데이터처리미니프로젝트]
# ###[일자 : 2025년 11월 4일]      [정삼용]         [컴퓨터AI공학과]

# %% [markdown]
# 2. 첨부한 영수증 사진(receipt.png)을 구글 드라이브에 업로드 후 코랩에 원본 이미지를 BGR 컬러 이미지로 출력하세요.

# %%
#구글 드라이브 마운트 하기
from google.colab import drive
drive.mount('/content/drive',force_remount=True)

# %%
#OpenCV로 이미지 디스플레이
import cv2
from google.colab.patches import cv2_imshow

imagePath ='/content/drive/MyDrive/photos/receipt.png' #이미지의 위치로 변경
image = cv2.imread(imagePath)

print("01. OpenCV BGR이미지 출력")
cv2_imshow(image)

# %% [markdown]
# 3. 영수증 사진을 흑백 사진으로 변환 후 출력하고

# %%
import cv2
from google.colab.patches import cv2_imshow  # for image display

imagePath ='/content/drive/MyDrive/photos/receipt.png' #이미지의 위치로 변경


image_grayscale = cv2.imread(imagePath,cv2.IMREAD_GRAYSCALE) # GRAYSCALE로 변환

cv2_imshow(image_grayscale)

# %% [markdown]
# 4. 영수증 이미지의 글씨가 명확하게 보이도록 스레시 홀딩 처리 후

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

imagePath ='/content/drive/MyDrive/photos/receipt.png' #이미지의 위치로 변경
grayImage = cv2.imread(imagePath, cv2.IMREAD_GRAYSCALE) # GRAYSCALE로 변환

adaptiveGaussian = cv2.adaptiveThreshold(grayImage,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY,7,11) # 스레시홀딩처리

adaptive = cv2.hconcat([adaptiveGaussian])
cv2_imshow(adaptive)

# %% [markdown]
# 5. 기하학적 변환을 사용해 영수증만 따로 이미지에서 추출하고 기울어지지 않은 직사각형 이미지로 변환 후 출력하세요.

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

image = mpimg.imread('/content/drive/MyDrive/photos/receipt.png')
(height, width, channel) = image.shape[:]

imgplot = plt.imshow(image)
plt.show()

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

image = cv2.imread('/content/drive/MyDrive/photos/receipt.png') #이미지의 위치로 변경
(height, width, channel) = image.shape[:]

#네 점의 좌표를 정한다.
P1 = (180,110)
P2 = (405,950)
P3 = (740,835)
P4 = (500,25)

# 이미지에 점 네 개 표시
cv2.circle(image, P1, 10, (0,0,255), -1)
cv2.circle(image, P2, 10, (0,255,0), -1)
cv2.circle(image, P3, 10, (0,255,255), -1)
cv2.circle(image, P4, 10, (255,0,0), -1)

#원본 이미지 출력
cv2_imshow(image)

# %%
# 두 점 사이의 거리 구하기
def distance(point1, point2):
  x1,y1 = point1
  x2,y2 = point2
  result = np.sqrt(np.power(x1 - x2, 2) + np.power(y1 - y2,2))
  return result

#ROI의 가로,세로 길이 구하기
envelope_width = max(int(distance(P1,P4)),int(distance(P2,P3)))
envelope_height = max(int(distance(P1,P2)), int(distance(P4,P3)))

print("[P1와 P4]",int(distance(P1,P4)),", [P2와 P3]",int(distance(P2,P3)))
print("[P1와 P2]",int(distance(P1,P2)),", [P4와 P3]",int(distance(P4,P3)))
print("envelope_width:",envelope_width,"envelope_height:",envelope_height)
print("\n")

#변환 전 네 점 위치와 변환 후 네 점 위치
pointsBefore = np.float32([P1, P2, P3, P4])
pointsAfter = np.float32([[0,0], [0,envelope_height], [envelope_width,envelope_height], [envelope_width,0]])


#원근변환 행렬 구하고 원근변환 적용
M = cv2.getPerspectiveTransform(pointsBefore,pointsAfter)
result = cv2.warpPerspective(image, M, (envelope_width, envelope_height))


#결과 이미지 출력
cv2_imshow(result)

# %% [markdown]
# 6. [토론점수 대체 가능 10점]  첨부한 카드 이미지(card.png)를 기하학적 변환을 사용해서 기울어지지 않은 직사각형 이미지로 따로 추출하세요.

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
import matplotlib.image as mpimg

image = mpimg.imread('/content/drive/MyDrive/photos/card.png') #이미지의 위치로 변경
(height, width, channel) = image.shape[:]

imgplot = plt.imshow(image)
plt.show()

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np

image = cv2.imread('/content/drive/MyDrive/photos/card.png') #이미지의 위치로 변경
(height, width, channel) = image.shape[:]

#네 점의 좌표를 정한다.
P1 = (105,240)
P2 = (370,550)
P3 = (685,270)
P4 = (410,40)

# 이미지에 점 네 개 표시
cv2.circle(image, P1, 10, (0,0,255), -1)
cv2.circle(image, P2, 10, (0,255,0), -1)
cv2.circle(image, P3, 10, (0,255,255), -1)
cv2.circle(image, P4, 10, (255,0,0), -1)

#원본 이미지 출력
cv2_imshow(image)

# %%
# 두 점 사이의 거리 구하기
def distance(point1, point2):
  x1,y1 = point1
  x2,y2 = point2
  result = np.sqrt(np.power(x1 - x2, 2) + np.power(y1 - y2,2))
  return result

#ROI의 가로,세로 길이 구하기
envelope_width = max(int(distance(P1,P4)),int(distance(P2,P3)))
envelope_height = max(int(distance(P1,P2)), int(distance(P4,P3)))

print("[P1와 P4]",int(distance(P1,P4)),", [P2와 P3]",int(distance(P2,P3)))
print("[P1와 P2]",int(distance(P1,P2)),", [P4와 P3]",int(distance(P4,P3)))
print("envelope_width:",envelope_width,"envelope_height:",envelope_height)
print("\n")

#변환 전 네 점 위치와 변환 후 네 점 위치
pointsBefore = np.float32([P1, P2, P3, P4])
pointsAfter = np.float32([[0,0], [0,envelope_height], [envelope_width,envelope_height], [envelope_width,0]])


#원근변환 행렬 구하고 원근변환 적용
M = cv2.getPerspectiveTransform(pointsBefore,pointsAfter)
result = cv2.warpPerspective(image, M, (envelope_width, envelope_height))


#결과 이미지 출력
cv2_imshow(result)
